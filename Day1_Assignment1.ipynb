# %% [markdown]
# <a href="https://colab.research.google.com/github/MannyP31/Let-s_Upgrade_Assignments/blob/master/Day1_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#QUESTION 1 

x=np.arange(40,50)
y=np.arange(50,60)
plt.plot(x,y,'go--',linewidth=2,markersize=7)
plt.title('Line Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
#QUESTION 2

days = [1,2,3,4,5,6,7]
sales_1 = [160,150,140,145,175,165,180]
sales_2 = [70,90,160,150,140,145,175]
plt.title("Sales Trend")
plt.xlabel("Days of week")
plt.ylabel("Sales")
plt.plot(days, sales_1, linestyle='dashed', color='red', marker ='o')
plt.plot(days, sales_2, linestyle='dashed', color='green', marker ='o')
plt.grid()
plt.show()

# %%
#ASSIGNMENT 3

x = [1,2,3,4]
y1 = [4,3,2,1]
y2 = [10,20,30,40]
y3 = [40,30,20,10]
y4 = [1,2,1,2]
y5 = [40,70,90,70]

plt.subplot(3,3,1)
plt.plot(x,y1,'r')
plt.subplot(3,3,2)
plt.plot(y4,x,'b')
plt.subplot(3,3,3)
plt.plot(x,y3,'y')
plt.subplot(3,3,4)
plt.plot(y1,y4,'g')
plt.subplot(3,3,5)
plt.plot(y3,y5,'c')
plt.subplot(3,3,6)
plt.plot(y2,y5,'m')
